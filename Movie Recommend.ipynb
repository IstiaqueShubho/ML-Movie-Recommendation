# %% [markdown]
# <a href="https://colab.research.google.com/github/IstiaqueShubho/ML-Movie-Recommendation/blob/main/Movie%20Recommend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("movie_dataset.csv")
# Out:
#       index  ...           director
# 0         0  ...      James Cameron
# 1         1  ...     Gore Verbinski
# 2         2  ...         Sam Mendes
# 3         3  ...  Christopher Nolan
# 4         4  ...     Andrew Stanton
# ...     ...  ...                ...
# 4798   4798  ...   Robert Rodriguez
# 4799   4799  ...       Edward Burns
# 4800   4800  ...        Scott Smith
# 4801   4801  ...        Daniel Hsia
# 4802   4802  ...   Brian Herzlinger
#
# [4803 rows x 24 columns]
